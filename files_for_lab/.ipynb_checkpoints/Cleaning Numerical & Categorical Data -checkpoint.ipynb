# %% [markdown]
# # 1. Import the necessary libraries.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df

# %%
customer_df = pd.read_csv('we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# # 3. First look at its main features (head, shape, info). NOTE The target column is total_claim_amount

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
customer_df.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
#total_claim_amount is the Target

# %% [markdown]
# # 4.Rename the columns so they follow the PE8 (snake case) (lower_case_with_underscores)

# %%
# Snake case column names
snake_case_columns = [column.lower().replace(" ", "_") for column in customer_df]

# Rename the columns
customer_df.columns = snake_case_columns

# %%
# Print the updated column names
print(customer_df.columns)
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# # 5. Change effective to date column to datetime format.

# %%
# Convert "Effective To Date" column to datetime format
customer_df["effective_to_date"] = pd.to_datetime(customer_df["effective_to_date"])

# Print the updated column names and data types

print(customer_df.dtypes)
# Out:
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                   int64
# months_since_policy_inception             int64
# number_of_open_complaints                 int64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# renew_offer_type                         object
# ...

# %% [markdown]
# # 6.Create a NEW dataframe using only the numerical data called numerical_df. Use this for the following questions.

# %%
# Select only numerical columns
numerical_df = customer_df.select_dtypes(include=[int, float])

# %%
numerical_df
# Out:
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months_since_last_claim  months_since_policy_inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %% [markdown]
# # 7. Define a function that differentiates between continuous and discrete variables. Hint: The number of unique values might be useful. Store continuous data into a continuous_df variable and do the same for discrete_df

# %%
for i in numerical_df:
    print(numerical_df[i].name)
    print(numerical_df[i].nunique()/len(numerical_df))
# Out:
# customer_lifetime_value
# 0.8803372016641121
# income
# 0.6233851543682943
# monthly_premium_auto
# 0.022115174074885044
# months_since_last_claim
# 0.003941318151959711
# months_since_policy_inception
# 0.010948105977665865
# number_of_open_complaints
# 0.0006568863586599519
# number_of_policies
# 0.0009853295379899278
# total_claim_amount
# 0.559010291219619

# %%
import pandas as pd

def categorize_variables(dataframe):
    continuous_df = pd.DataFrame()  # Initialize empty DataFrame for continuous variables
    discrete_df = pd.DataFrame()    # Initialize empty DataFrame for discrete variables

    for column in dataframe.columns:
        unique_values = dataframe[column].nunique()
        if unique_values > 0.50:  # Set a threshold (0.50) to determine if a variable is continuous or discrete
            continuous_df[column] = dataframe[column]
        else:
            discrete_df[column] = dataframe[column]

    return continuous_df, discrete_df

# %% [markdown]
# # 8. Plot a correlation matrix

# %%
# Calculate correlation matrix
correlation_matrix = numerical_df.corr()

# Generate heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
# Variables with a strong positive correlation (values close to 1) are indicated by dark red squares. 
# This suggests that as one variable increases, the other tends to increase as well.

# Variables with a strong negative correlation (values close to -1) are indicated by dark blue squares. 
# This suggests that as one variable increases, the other tends to decrease.

# Variables with weak or no correlation (values close to 0) are indicated by lighter colors, such as white or pale yellow.

# %% [markdown]
# # 9. Create a function to plot every discrete variable. Do the same with the continuous variables (Be Careful, you may need to change the plot type to one better suited for continuous data!)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plot_discrete_variables(dataframe):
    discrete_vars = dataframe.select_dtypes(include=['object', 'category', 'bool'])  # Select discrete variables

    for column in discrete_vars.columns:
        plt.figure(figsize=(6, 4))
        sns.countplot(data=dataframe, x=column)
        plt.title(f"{column} Count")
        plt.xlabel(column)
        plt.ylabel("Count")
        plt.xticks(rotation=45)
        plt.show()

# %%
def plot_continuous_variables(dataframe):
    continuous_vars = dataframe.select_dtypes(include=['int64', 'float64'])  # Select continuous variables

    for column in continuous_vars.columns:
        plt.figure(figsize=(6, 4))
        sns.histplot(data=dataframe, x=column, kde=True)
        plt.title(f"{column} Distribution")
        plt.xlabel(column)
        plt.ylabel("Frequency")
        plt.show()

# %%
continuous_df, discrete_df = categorize_variables(numerical_df)
plot_discrete_variables(discrete_df)
plot_continuous_variables(continuous_df)

# %% [markdown]
# # 10. Comment what you see

# %%
#The countplot for each discrete variable shows the frequency of each unique value in the variable.
#The histogram plot with KDE (kernel density estimation) shows the distribution of values for each continuous variable.

# %% [markdown]
# # 11.Look for outliers in the continuous variables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_continuous_variables(dataframe):
    continuous_vars = dataframe.select_dtypes(include=['int64', 'float64'])  # Select continuous variables

    for column in continuous_vars.columns:
        plt.figure(figsize=(8, 6))
        plt.subplot(1, 2, 1)
        sns.histplot(data=dataframe, x=column, kde=True)
        plt.title(f"{column} Distribution")
        plt.xlabel(column)
        plt.ylabel("Frequency")

        plt.subplot(1, 2, 2)
        sns.boxplot(data=dataframe, y=column)
        plt.title(f"{column} Boxplot")
        plt.ylabel(column)

        plt.tight_layout()
        plt.show()

# %%
# Call the function with the appropriate dataframe
plot_continuous_variables(continuous_df)

# %% [markdown]
# # 12. Comment what you see

# %%
#

# %% [markdown]
# # 13. Check all columns for NaN values. Decide what (if anything) you will need to do with them, do that now.

# %%
numerical_df.isna().sum()
# Out:
# customer_lifetime_value          0
# income                           0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# total_claim_amount               0
# dtype: int64

# %% [markdown]
# # #14.Save the numerical_df to csv as numerical.csv You will use this file again this week.

# %%
numerical_df.to_csv('categorical.csv', index=False)

# %% [markdown]
# # Lab | Cleaning categorical data

# %% [markdown]
# # 1 Open the notebook created for Lab-cleaning-numerical-data.

# %%
customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# # 2 Find all of the categorical data. Save it in a categorical_df variable.

# %%
categorical_df = customer_df.select_dtypes(include=[object])

# %%
categorical_df
# Out:
#      customer       state response  coverage education employmentstatus  \
# 0     BU79786  Washington       No     Basic  Bachelor         Employed
# 1     QZ44356     Arizona       No  Extended  Bachelor       Unemployed
# 2     AI49188      Nevada       No   Premium  Bachelor         Employed
# 3     WW63253  California       No     Basic  Bachelor       Unemployed
# 4     HB64268  Washington       No     Basic  Bachelor         Employed
# ...       ...         ...      ...       ...       ...              ...
# 9129  LA72316  California       No     Basic  Bachelor         Employed
# 9130  PK87824  California      Yes  Extended   College         Employed
# 9131  TD14365  California       No  Extended  Bachelor       Unemployed
# 9132  UP19263  California       No  Extended   College         Employed
# 9133  Y167826  California       No  Extended   College       Unemployed
#
#      gender location_code marital_status     policy_type        policy  \
# ...

# %% [markdown]
# # 3.Check for NaN values and decide what to do with them, do it now.

# %%
categorical_df.isna().sum()
# No NaN values here
# Out:
# customer            0
# state               0
# response            0
# coverage            0
# education           0
# employmentstatus    0
# gender              0
# location_code       0
# marital_status      0
# policy_type         0
# policy              0
# renew_offer_type    0
# sales_channel       0
# vehicle_class       0
# vehicle_size        0
# dtype: int64

# %% [markdown]
# # 4.Check all unique values of columns.

# %%
for column in categorical_df.columns:
    unique_values = categorical_df[column].unique()
    print(f"Unique values in {column}:")
    print(unique_values)
# Out:
# Unique values in customer:
# ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# Unique values in state:
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# Unique values in response:
# ['No' 'Yes']
# Unique values in coverage:
# ['Basic' 'Extended' 'Premium']
# Unique values in education:
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# Unique values in employmentstatus:
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# Unique values in gender:
# ['F' 'M']
# Unique values in location_code:
# ['Suburban' 'Rural' 'Urban']
# Unique values in marital_status:
# ['Married' 'Single' 'Divorced']
# Unique values in policy_type:
# ['Corporate Auto' 'Personal Auto' 'Special Auto']
# Unique values in policy:
# ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# Unique values in renew_offer_type:
# ['Offer1' 'Offer3' 'Offer2' 'Offer4']
# ...

# %% [markdown]
# # 5 Check dtypes. Do they all make sense as categorical data?

# %%
categorical_df.dtypes
# it shows that all are categorical data
# Out:
# customer            object
# state               object
# response            object
# coverage            object
# education           object
# employmentstatus    object
# gender              object
# location_code       object
# marital_status      object
# policy_type         object
# policy              object
# renew_offer_type    object
# sales_channel       object
# vehicle_class       object
# vehicle_size        object
# dtype: object

# %%
categorical_df.head()
# Out:
#   customer       state response  coverage education employmentstatus gender  \
# 0  BU79786  Washington       No     Basic  Bachelor         Employed      F
# 1  QZ44356     Arizona       No  Extended  Bachelor       Unemployed      F
# 2  AI49188      Nevada       No   Premium  Bachelor         Employed      F
# 3  WW63253  California       No     Basic  Bachelor       Unemployed      M
# 4  HB64268  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
# ...

# %% [markdown]
# # 6 Does any column contain alpha and numeric data? Decide how to clean it and do it now.

# %%
# The column Customer has alphanumeric data so I decided to delete this column
categorical_df = categorical_df.drop('customer', axis=1)

# %%
categorical_df.head()
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# ...

# %% [markdown]
# # 7.Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions and do it now

# %%
# Handle missing values
categorical_df.dropna(inplace=True)  # Remove rows with missing values if any

# %% [markdown]
# # 8.Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# %% [markdown]
# '''Policy_type: This column represents the general type or category of insurance policy that a customer holds.
# The unique values in this column are "Corporate Auto," "Personal Auto," and "Special Auto."
# It suggests that the policies can be categorized into three types based on the insurance coverage or purpose.
#
# Policy: This column provides more specific information about the insurance policies. It contains a combination of the policy
# type and a code or identifier. The unique values in this column include "Corporate L3," "Personal L3," "Corporate L2,"
# "Personal L1," "Special L2," "Corporate L1," "Personal L2," "Special L1," and "Special L3." Each value represents a
# specific policy within the corresponding policy type.'''

# %% [markdown]
# # 9.Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %%
column_unique_counts = categorical_df.nunique()
print(column_unique_counts)
# Out:
# state               5
# response            2
# coverage            3
# education           5
# employmentstatus    5
# gender              2
# location_code       3
# marital_status      3
# policy_type         3
# policy              9
# renew_offer_type    4
# sales_channel       4
# vehicle_class       6
# vehicle_size        3
# dtype: int64

# %%
# Combine state and location_code columns
# Since both columns represent geographical information, you could consider combining them into a single categorical feature
categorical_df['state_location'] = categorical_df['state'] + ' - ' + categorical_df['location_code']
categorical_df.drop(['state', 'location_code'], axis=1, inplace=True)

# %%
# Combine policy_type and policy columns
#These two columns are related and represent different aspects of insurance policies.
categorical_df['combined_policy'] = categorical_df['policy_type'] + ' - ' + categorical_df['policy']
categorical_df.drop(['policy_type', 'policy'], axis=1, inplace=True)

# %%
# Combine policy_type and policy columns
#These two columns are related and represent data of vehicle 
categorical_df['combined_vehicle'] = categorical_df['vehicle_class'] + ' - ' + categorical_df['vehicle_size']
categorical_df.drop(['vehicle_class', 'vehicle_size'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vehicle_class'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
categorical_df
# Out:
#      response  coverage education employmentstatus gender marital_status  \
# 0          No     Basic  Bachelor         Employed      F        Married
# 1          No  Extended  Bachelor       Unemployed      F         Single
# 2          No   Premium  Bachelor         Employed      F        Married
# 3          No     Basic  Bachelor       Unemployed      M        Married
# 4          No     Basic  Bachelor         Employed      M         Single
# ...       ...       ...       ...              ...    ...            ...
# 9129       No     Basic  Bachelor         Employed      M        Married
# 9130      Yes  Extended   College         Employed      F       Divorced
# 9131       No  Extended  Bachelor       Unemployed      M         Single
# 9132       No  Extended   College         Employed      M        Married
# 9133       No  Extended   College       Unemployed      M         Single
#
#      renew_offer_type sales_channel         state_location  \
# ...

# %% [markdown]
# # 10.Save the cleaned catagorical dataframe as categorical.csv You will use this file again this week.

# %%
categorical_df.to_csv('categorical.csv', index=False)
